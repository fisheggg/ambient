# %%
import os

from anglegram import plot_anglegram, compute_anglegram_from_aem

# %%
import numpy as np

aem = np.load("../audio/trimmed/AEM/B_sync_H_Mic5_230602_005.npy")
# Out:
# (1093, 180, 360)

# %%
compute_aem(
    audio_dir='../audio/trimmed/Bformat/',
    save_dir='../audio/trimmed/AEM',
    fps=20,
    audio_frame_length=4800,
    aem_width=360, # angular_res = 1
    aem_height=180,
    gpu=True,
    batch_size=20
)
# Out:
# => Found 15 audio files in ../audio/trimmed/Bformat/.
# Using GPU for AEM computation.
# => Computing AEM for ../audio/trimmed/Bformat/B_sync_1.5H_Mic3_230602_007.wav:   0%|          | 0/15 [00:00<?, ?it/s]/fp/homes01/u01/ec-jinyueg/felles/Research/Project/AMBIENT/RoomAmbisonicsPaper/analysis/ambisonics/spherical_maps.py:110: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   data_in = torch.from_numpy(data[i, :, :, :]).cuda()
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# ...

# %%
time, phi, nu, rms = plot_anglegram(
    *compute_anglegram_from_aem("/fp/homes01/u01/ec-jinyueg/felles_/Research/Project/AMBIENT/RoomAmbisonicsPaper/audio/trimmed/AEM/B_sync_H_Mic5_230602_005.npz"),
    db_threshold=-40,
    db_max=-20,
    title="B_sync_H_Mic5_230602_005.wav",
)

# %%
time, phi, nu, rms = plot_anglegram(
    "../audio/trimmed/Bformat/B_sync_1.5H_Mic5_230602_007.wav",
    format="AmbiX",
    time_res=0.1,
    db_threshold=-40,
    start=0,
    duration=60,
)

# %%
plot_anglegram(
    "../audio/trimmed/Bformat/B_sync_Hby2_Mic5_230602_006.wav",
    format="AmbiX",
    time_res=0.1,
    db_threshold=-40,
    start=0,
    duration=60,
)
# Out:
# (array([ 0. ,  0.4,  0.5,  0.9,  1. ,  1.4,  1.5,  1.9,  2. ,  2.4,  2.5,
#          2.9,  3. ,  3.4,  3.5,  3.9,  4. ,  4.4,  4.5,  4.9,  5. ,  5.4,
#          5.5,  5.9,  6. ,  6.4,  6.5,  6.9,  7. ,  7.4,  7.5,  7.9,  8. ,
#          8.4,  8.5,  8.9,  9. ,  9.4,  9.5,  9.9, 10. , 10.4, 10.5, 10.9,
#         11. , 11.4, 11.5, 11.9, 12. , 12.4, 12.5, 12.9, 13. , 13.4, 13.5,
#         13.9, 14. , 14.4, 14.5, 14.9, 15. , 15.4, 15.5, 15.9, 16. , 16.4,
#         16.5, 16.9, 17. , 17.4, 17.5, 17.9, 18. , 18.4, 18.5, 18.9, 19. ,
#         19.4, 19.5, 19.9, 20. , 20.4, 20.5, 20.9, 21. , 21.4, 21.5, 21.9,
#         22. , 22.4, 22.5, 22.9, 23. , 23.4, 23.5, 23.9, 24. , 24.4, 24.5,
#         24.9, 25. , 25.4, 25.5, 25.9, 26. , 26.4, 26.5, 26.9, 27. , 27.4,
#         27.5, 27.9, 28. , 28.4, 28.5, 28.9, 29. , 29.4, 29.5, 29.9, 30. ,
#         30.4, 30.5, 30.9, 31. , 31.4, 31.5, 31.9, 32. , 32.4, 32.5, 32.9,
#         33. , 33.4, 33.5, 33.9, 34. , 34.4, 34.5, 34.9, 35. , 35.4, 35.5,
# ...

# %%
plot_anglegram(
    "../audio/zoom_expt.wav",
    format="AmbiX",
    time_res=0.1,
    db_threshold=-40,
    start=0,
    duration=60,
)
# Out:
# (array([ 0.4,  1. ,  1.4,  1.6,  2. ,  3.2,  4.8,  5. ,  5.4,  5.6,  5.8,
#          6. ,  6.2,  6.6,  6.8,  7.2,  7.8,  8.2,  8.4,  8.8,  9. ,  9.4,
#         10. , 10.6, 11. , 13. , 15.6, 16.2, 16.8, 17.2, 17.4, 17.8, 18.4,
#         18.6, 19. , 19.6, 20.2, 20.6, 20.8, 21.2, 21.4, 21.8, 23.8, 24.2,
#         24.4, 24.8, 25. , 25.4, 25.6, 26. , 26.2, 26.4, 26.6, 26.8, 27.2,
#         27.4, 27.6, 27.8, 28.2, 28.4, 28.8, 29. , 29.4, 29.8, 30. , 30.4,
#         30.6, 32.6, 32.8, 33.2, 33.4, 33.8, 34.2, 34.4, 34.8, 35. , 35.2,
#         35.4, 35.8, 36. , 36.4, 36.8, 37. , 37.4, 37.6, 38. , 38.4, 38.6,
#         39. , 39.2, 39.4, 39.6, 41.6, 41.8, 42. , 42.2, 42.4, 42.6, 42.8,
#         43. , 43.2, 43.4, 43.6, 43.8, 44. , 44.2, 44.4, 44.6, 44.8, 45. ,
#         45.2, 45.4, 45.6, 45.8, 46. , 46.2, 46.4, 46.6, 46.8, 47. , 47.2,
#         47.4, 47.6, 47.8, 48. , 48.2, 48.4, 50.6, 50.8, 51. , 51.2, 51.4,
#         51.6, 51.8, 52. , 52.2, 52.4]),
# ...

# %%
plot_anglegram(
    "../SyncedAudio/H_Mic1_230602_005.wav",
    format="AmbiX",
    time_res=0.2,
    db_threshold=-45,
    start=0,
    duration=60,
)

# %%
plot_anglegram(
    "../SyncedAudio/H_Mic2_230602_005.wav",
    format="AmbiX",
    time_res=0.2,
    db_threshold=-45,
    start=0,
    duration=60,
)

# %%
plot_anglegram(
    "../SyncedAudio/H_Mic3_230602_005.wav",
    format="AmbiX",
    time_res=0.2,
    db_threshold=-45,
    start=0,
    duration=60,
)

# %%
plot_anglegram(
    "../SyncedAudio/H_Mic4_230602_005.wav",
    format="AmbiX",
    time_res=0.2,
    db_threshold=-45,
    start=0,
    duration=60,
)
